# %%
import pandas as pd

# %%
df = pd.DataFrame()
df_gen = pd.read_csv("../Dzien02/sales-records.csv", chunksize=95_123)
for chunk in df_gen:
    chunk = chunk.query(" `Units Sold`>=300 and `Units Sold`<=3000 ") # przefiltrowany fragment pliku CSV
    df = df.append(chunk)
    print(".", end="")
df
# Out:
# ...........
#                        Region                Country        Item Type  \
# 0          Sub-Saharan Africa           South Africa           Fruits
# 2       Australia and Oceania       Papua New Guinea             Meat
# 3          Sub-Saharan Africa               Djibouti          Clothes
# 5                        Asia              Sri Lanka           Fruits
# 6          Sub-Saharan Africa            Seychelles         Beverages
# ...                       ...                    ...              ...
# 999963     Sub-Saharan Africa           South Africa       Vegetables
# 999973     Sub-Saharan Africa  Sao Tome and Principe           Snacks
# 999975                 Europe              Lithuania           Snacks
# 999985                   Asia            North Korea  Office Supplies
# 999986     Sub-Saharan Africa  Republic of the Congo        Cosmetics
#
#        Sales Channel Order Priority Order Date   Order ID   Ship Date  \
# ...
